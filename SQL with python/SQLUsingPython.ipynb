# %% [markdown]
# # SQL using python
#
# The aim of this project is to perform SQL queries using python. This project allows us to combine the powers of SQL and Python. While SQL has strengths in querying data from data bases cotaining millions of rows with great ease, there are several data manupulation and visualization libraries provided by python like Pandas, numpy, matplotlib and seaborn. We will load the data which is in CSV format and upload it to .db database and then query data from there and analyse it using python. It is also possible to create a new database using python, and update and manipulate the items in the existing database.
#
# #### First we create a database and start querying and manipulating it

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("SQLiteMagic.db")    # Creating database SQLiteMagic.db
cur = con.cursor()

# %%
#Connecting to database SQLiteMagic.db
# %sql sqlite:///SQLiteMagic.db

# %% [markdown]
# ##### %%sql is used in the beginning of the cell to treat entire cell as sql. In the following cell we load some AI generated data.

# %%
# %%sql
#
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country, first_name, last_name, test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#  * sqlite:///SQLiteMagic.db
# (sqlite3.OperationalError) table INTERNATIONAL_STUDENT_TEST_SCORES already exists
# [SQL: CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import prettytable   # Importing the 'prettytable' library, which is used to display data in a formatted table

prettytable.DEFAULT = 'DEFAULT'   # Setting the default display format for prettytable to 'DEFAULT' (i.e., a simple table format)

# %%
country = "Canada"
# One can use python variables in SQL statements by adding a ":" prefix to the python variable names.
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country = :country
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49)]

# %%
# Assigning SQL query results to a dataframe

test_score_distribution = %sql SELECT test_score as "Test_Score", count(*) as "Frequency" from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score;
test_score_distribution
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [(38, 2),
#  (40, 1),
#  (43, 2),
#  (44, 2),
#  (45, 8),
#  (46, 7),
#  (47, 4),
#  (48, 14),
#  (49, 8),
#  (50, 10),
#  (51, 8),
#  (52, 8),
#  (53, 8),
#  (54, 5),
#  (55, 4),
#  (56, 1),
#  (57, 2),
#  (58, 4),
#  (60, 1)]

# %%
# Converting test score distribution to a dataframe    

dataframe = test_score_distribution.DataFrame()



import seaborn

plot = seaborn.barplot(x='Test_Score',y='Frequency', data=dataframe)

# %% [markdown]
# ## In the next part I will take data from the online links, inject into a SQL database and that extract the data from there and analyze.

# %%
import pandas as pd
df1 = pd.read_csv("ChicagoCensusData (1).csv")
df2 = pd.read_csv("ChicagoPublicSchools (1).csv")
df3 = pd.read_csv("ChicagoCrimeData (1).csv")

# %% [markdown]
# ### A brief description of the datasets is as follows. And more information can be found at the given links.
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
#
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2]
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
#
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t]
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
#
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2]

# %% [markdown]
# #### Creating a database.

# %%
import csv, sqlite3

con = sqlite3.connect("RealWorldData.db")
cur = con.cursor()

# %%
import prettytable
prettytable.DEFAULT = 'DEFAULT'

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# #### Establishing connection with the database

# %%
# %sql sqlite:///RealWorldData.db

# %% [markdown]
# #### Uploading pandas dataframes as tables in the sql database.

# %%
df1.to_sql("CHICAGO_CENSUS_DATA", con, if_exists='replace', index=False, method="multi")
df2.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA", con, if_exists='replace', index=False, method="multi")
df3.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method="multi")
# Out:
# 533

# %% [markdown]
# #### A list of all the tables present in the database.

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('CHICAGO_CENSUS_DATA',),
#  ('CHICAGO_PUBLIC_SCHOOLS_DATA',),
#  ('CHICAGO_CRIME_DATA',)]

# %% [markdown]
# #### Finding the total number of crimes recorded in the CRIME table.

# %%
# %%sql
#
# SELECT COUNT(*) AS TOTAL_CRIMES
# FROM CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [(533,)]

# %% [markdown]
# #### Community area names and numbers with per capita income less than 11000.

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME,
#        COMMUNITY_AREA_NUMBER,
#        PER_CAPITA_INCOME
# FROM CHICAGO_CENSUS_DATA
# WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('West Garfield Park', 26.0, 10934),
#  ('South Lawndale', 30.0, 10402),
#  ('Fuller Park', 37.0, 10432),
#  ('Riverdale', 54.0, 8201)]

# %% [markdown]
# #### All case numbers for crimes involving minors.

# %%
# %%sql
#
# SELECT CASE_NUMBER
# FROM CHICAGO_CRIME_DATA
# WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# #### All kidnapping crimes involving a child

# %%
# %%sql
#
#
# SELECT *
# FROM CHICAGO_CRIME_DATA
# WHERE PRIMARY_TYPE = 'KIDNAPPING'
#   AND DESCRIPTION LIKE '%CHILD%';
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# #### The kind of crimes that were recorded at schools (no repetitions).

# %%
# %%sql
#
# SELECT DISTINCT PRIMARY_TYPE
# FROM CHICAGO_CRIME_DATA
# WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%';
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# #### Type of schools along with the average safety score for each type.

# %%
# %%sql
#
# SELECT "Elementary, Middle, or High School" AS SCHOOL_TYPE,
#        AVG(SAFETY_SCORE) AS AVERAGE_SAFETY_SCORE
# FROM CHICAGO_PUBLIC_SCHOOLS_DATA
# GROUP BY "Elementary, Middle, or High School";
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %% [markdown]
# #### Finding community areas with highest percentage of households below poverty line.

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME,
#        PERCENT_HOUSEHOLDS_BELOW_POVERTY
# FROM CHICAGO_CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC
# LIMIT 5;
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# #### Finding community area which is most crime prone.

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NUMBER
# FROM CHICAGO_CRIME_DATA
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY COUNT(*) DESC
# LIMIT 1;
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [(25.0,)]

# %% [markdown]
# #### Finding the name of the community area with highest hardship index.

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME
# FROM CHICAGO_CENSUS_DATA
# WHERE HARDSHIP_INDEX = (
#     SELECT MAX(HARDSHIP_INDEX)
#     FROM CHICAGO_CENSUS_DATA
# );
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# #### Determining the community area name with most number of crimes.

# %%
# %%sql
#
#
# SELECT COMMUNITY_AREA_NAME
# FROM CHICAGO_CENSUS_DATA
# WHERE COMMUNITY_AREA_NUMBER = (
#     SELECT COMMUNITY_AREA_NUMBER
#     FROM CHICAGO_CRIME_DATA
#     GROUP BY COMMUNITY_AREA_NUMBER
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# );
# Out:
#  * sqlite:///RealWorldData.db
#    sqlite:///SQLiteMagic.db
# Done.
# [('Austin',)]
